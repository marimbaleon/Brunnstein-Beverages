# %% [markdown]
# # Data generator
#
# Generate Brunnstein's synthetic data (master + transactions across 2023-2025) and load into DSQL. Run this whenever you want a fresh dataset.
#
# Reads `DSQL_CLUSTER_ID` / `AWS_REGION` / `AWS_PROFILE` from `.env`. Falls back to local SQLite if those are unset.

# %%
import sys
from pathlib import Path

here = Path.cwd()
project_root = here if (here / "pyproject.toml").exists() else here.parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

# %%
from data.data_generator import main as load_data

counts = load_data(seed=42, year_range=(2023, 2025), reset=True)
counts
